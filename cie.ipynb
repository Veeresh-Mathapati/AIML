# %% [markdown]
# <a href="https://colab.research.google.com/github/Veeresh-Mathapati/AIML/blob/main/cie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='iris.csv'
df=pd.read_csv('iris.csv')
df.columns=['sepal length','sepal width','petal length','petal width','class']
print(df.columns)
x=df['sepal length']
y=df['sepal width']
plt.hist(x)
plt.xlabel('sepal length in cm')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')
